# %% [markdown]
# # Predicting Toronto Ferry Activity

# %%
from Model import RedemptionModel
import pandas as pd
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
def load_data(file):
    # generic data processing function
    df = pd.read_csv(file,
                dtype={'_id':int, 'Redemption Count': int, 'Sales Count':int},
                parse_dates=['Timestamp'])
    df.sort_values('Timestamp', inplace=True)
    # convert to time-aware
    df.set_index('Timestamp', inplace=True)
    df_daily = df.resample('d').sum()
    # engineer some time features 
    df_daily['monthly'] = df_daily.reset_index().Timestamp.dt.month.values
    df_daily['quarter'] = df_daily.reset_index().Timestamp.dt.quarter.values
    return df_daily

# %%
df = load_data('./data/Toronto Island Ferry Ticket Counts.csv')

# %%
rm = RedemptionModel(df, 'Redemption Count')
sm = RedemptionModel(df,'Sales Count')

# %%
rm.run_models()
# Out:
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.237531
# is_holiday     0.125801
# day_of_year    0.105803
# year           0.100733
# month          0.100649
# tmin           0.096576
# day_of_week    0.075777
# tmax           0.050768
# lag_365        0.050607
# monthly        0.024813
# prcp           0.022492
# snow           0.008449
# wspd           0.000000
# dtype: float32
# ------------------------------
# 02:32:50 - cmdstanpy - INFO - Chain [1] start processing
# 02:32:50 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.207584
# is_holiday     0.175797
# month          0.096176
# year           0.094110
# day_of_year    0.093246
# tmin           0.090554
# day_of_week    0.078138
# tmax           0.047780
# lag_365        0.045576
# monthly        0.029878
# prcp           0.019786
# snow           0.017343
# wspd           0.004033
# dtype: float32
# ------------------------------
# 02:32:52 - cmdstanpy - INFO - Chain [1] start processing
# 02:32:52 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.202741
# is_holiday     0.168231
# tmin           0.113545
# day_of_year    0.100273
# year           0.096352
# day_of_week    0.092996
# month          0.067316
# lag_365        0.046840
# tmax           0.043116
# monthly        0.022941
# prcp           0.019482
# wspd           0.015753
# snow           0.010413
# dtype: float32
# ------------------------------
# 02:32:54 - cmdstanpy - INFO - Chain [1] start processing
# 02:32:54 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# is_holiday     0.170929
# quarter        0.162163
# tmin           0.120107
# day_of_year    0.104228
# day_of_week    0.097821
# month          0.094166
# year           0.088218
# lag_365        0.048663
# tmax           0.041047
# monthly        0.025009
# prcp           0.019236
# wspd           0.016739
# snow           0.011673
# dtype: float32
# ------------------------------
# 02:32:56 - cmdstanpy - INFO - Chain [1] start processing
# 02:32:56 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sm.run_models()
# Out:
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.317838
# month          0.102126
# year           0.092344
# is_holiday     0.087655
# day_of_year    0.085970
# tmin           0.075103
# snow           0.057041
# day_of_week    0.054224
# tmax           0.049583
# lag_365        0.038114
# monthly        0.024589
# prcp           0.015413
# wspd           0.000000
# dtype: float32
# ------------------------------
# 02:32:59 - cmdstanpy - INFO - Chain [1] start processing
# 02:32:59 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.218450
# is_holiday     0.184107
# tmin           0.107781
# day_of_year    0.098417
# month          0.087864
# year           0.081824
# day_of_week    0.064355
# tmax           0.045952
# lag_365        0.041746
# monthly        0.038145
# prcp           0.019528
# snow           0.008347
# wspd           0.003484
# dtype: float32
# ------------------------------
# 02:33:01 - cmdstanpy - INFO - Chain [1] start processing
# 02:33:01 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.222469
# is_holiday     0.144908
# tmin           0.110249
# day_of_year    0.103449
# month          0.102258
# year           0.088333
# day_of_week    0.072391
# tmax           0.049014
# lag_365        0.038948
# monthly        0.026639
# prcp           0.020303
# wspd           0.011390
# snow           0.009649
# dtype: float32
# ------------------------------
# 02:33:03 - cmdstanpy - INFO - Chain [1] start processing
# 02:33:03 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.161993
# month          0.153523
# is_holiday     0.152110
# tmin           0.115492
# day_of_year    0.104421
# year           0.078821
# day_of_week    0.074711
# tmax           0.051442
# lag_365        0.044832
# monthly        0.025677
# prcp           0.017446
# wspd           0.012985
# snow           0.006547
# dtype: float32
# ------------------------------
# 02:33:05 - cmdstanpy - INFO - Chain [1] start processing
# 02:33:05 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# print model summary stats
sm.results
# Out:
# {'Base': {0: [0.8644586846103235,
#    2293.676391024557,
#    np.float64(3630.077794842359)],
#   1: [0.8274146708828738, 2483.8766123227174, np.float64(3840.3948773050943)],
#   2: [0.8278688114240099, 2414.3481063240597, np.float64(3522.655627162959)],
#   3: [0.8492490654061912, 2365.0867360619695, np.float64(3448.405780238512)]},
#  'XGBoost': {0: [1.663657546043396,
#    1150.247802734375,
#    np.float64(1970.6597245592654)],
#   1: [0.5691967010498047, 1483.8720703125, np.float64(2587.671250371654)],
#   2: [0.5305941104888916, 1208.1832275390625, np.float64(2027.5978398094628)],
#   3: [8018577776967680.0, 1202.8033447265625, np.float64(2017.979434979455)]},
#  'Prophet': {0: [0.8137967560439632,
#    1528.655297792021,
#    np.float64(2437.5873542493487)],
#   1: [1.0101184583941587, 1583.3812036672336, np.float64(2479.3006089197)],
#   2: [0.8277315946510545, 1394.9792217016516, np.float64(2106.199325726138)],
#   3: [3.082494697446974e+16,
#    1393.50751270552,
#    np.float64(2087.4576642788825)]}}

# %%
rm.run_models()
# Out:
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.237531
# is_holiday     0.125801
# day_of_year    0.105803
# year           0.100733
# month          0.100649
# tmin           0.096576
# day_of_week    0.075777
# tmax           0.050768
# lag_365        0.050607
# monthly        0.024813
# prcp           0.022492
# snow           0.008449
# wspd           0.000000
# dtype: float32
# ------------------------------
# 02:33:08 - cmdstanpy - INFO - Chain [1] start processing
# 02:33:08 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.207584
# is_holiday     0.175797
# month          0.096176
# year           0.094110
# day_of_year    0.093246
# tmin           0.090554
# day_of_week    0.078138
# tmax           0.047780
# lag_365        0.045576
# monthly        0.029878
# prcp           0.019786
# snow           0.017343
# wspd           0.004033
# dtype: float32
# ------------------------------
# 02:33:10 - cmdstanpy - INFO - Chain [1] start processing
# 02:33:10 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# quarter        0.202741
# is_holiday     0.168231
# tmin           0.113545
# day_of_year    0.100273
# year           0.096352
# day_of_week    0.092996
# month          0.067316
# lag_365        0.046840
# tmax           0.043116
# monthly        0.022941
# prcp           0.019482
# wspd           0.015753
# snow           0.010413
# dtype: float32
# ------------------------------
# 02:33:12 - cmdstanpy - INFO - Chain [1] start processing
# 02:33:12 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# XGBoost Feature Importances:
# is_holiday     0.170929
# quarter        0.162163
# tmin           0.120107
# day_of_year    0.104228
# day_of_week    0.097821
# month          0.094166
# year           0.088218
# lag_365        0.048663
# tmax           0.041047
# monthly        0.025009
# prcp           0.019236
# wspd           0.016739
# snow           0.011673
# dtype: float32
# ------------------------------
# 02:33:14 - cmdstanpy - INFO - Chain [1] start processing
# 02:33:14 - cmdstanpy - INFO - Chain [1] done processing
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rm.results
# Out:
# {'Base': {0: [0.872908225415014,
#    2460.4206353662353,
#    np.float64(3930.1367604394554)],
#   1: [0.8342954028320085, 2579.075919933576, np.float64(4043.757389035545)],
#   2: [0.8292041319135574, 2524.804708702076, np.float64(3773.6946560925903)],
#   3: [0.8675836132150535, 2504.9517485548217, np.float64(3631.953611821037)]},
#  'XGBoost': {0: [1.456287044861952e+16,
#    1169.508056640625,
#    np.float64(2033.7392286131474)],
#   1: [8999650312847360.0, 1458.4129638671875, np.float64(2527.521117617022)],
#   2: [0.4997367560863495, 1336.520263671875, np.float64(2232.925547348142)],
#   3: [1.896334576372941e+16,
#    1330.4442138671875,
#    np.float64(2325.079245961307)]},
#  'Prophet': {0: [0.7850433636876119,
#    1694.2143706834665,
#    np.float64(2741.074892127078)],
#   1: [2.8486092502768216e+16,
#    1757.2568432203734,
#    np.float64(2769.051153580028)],
#   2: [0.7903878835630185, 1570.4775676654112, np.float64(2378.810429810305)],
#   3: [4.073694664347818e+16,
#    1505.7961615486386,
#    np.float64(2268.022938122355)]}}

# %%
1330.4442138671875/2504.9517485548217
# Out:
# 0.5311256852092097
